# %%
import time

from utils.load_data import load_split

# %%
time_start = time.time()
_, _ = load_split("data/train/", library="cv2")
_, _ = load_split("data/test/", library="cv2")
time_end = time.time()
print(f"OpenCV Loading time: {time_end - time_start:.2f} seconds")
# Out:
# OpenCV Loading time: 116.83 seconds

# %%
time_start = time.time()
_, _ = load_split("data/train/", library="pil")
_, _ = load_split("data/test/", library="pil")
time_end = time.time()
print(f"PIL Loading time: {time_end - time_start:.2f} seconds")
# Out:
# PIL Loading time: 81.22 seconds

# %%
time_start = time.time()
_, _ = load_split("data/train/", library="skimage")
_, _ = load_split("data/test/", library="skimage")
time_end = time.time()
print(f"Scikit-image Loading time: {time_end - time_start:.2f} seconds")
# Out:
# Scikit-image Loading time: 234.01 seconds
